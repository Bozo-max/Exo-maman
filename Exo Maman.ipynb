# %%
from math import sqrt, pow, log

def Briggs(x, p):
    n = 0
    while abs(x - 1) > p:
        x = sqrt(x)
        n += 1
    return (x - 1) * pow(2, n)

# %%
print("Briggs(2,10^-3) = ", Briggs(2, 1e-3))
print("ln(2) = ", log(2))
print("Briggs(0.8,10^-3) = ", Briggs(0.8, 1e-3))
print("ln(0.8) = ", log(0.8))
print()


for n in range(3, 8):
    print("Briggs(2,10^",-n,") = ", Briggs(2, pow(10,-n)), sep="")
    print("Briggs(2,10^", -n, ") - ln(2)= ", Briggs(2, pow(10, -n))-log(2), sep="")
    print()
# Out:
# Briggs(2,10^-3) =  0.6933818297000016
# ln(2) =  0.6931471805599453
# Briggs(0.8,10^-3) =  -0.22304632752474163
# ln(0.8) =  -0.2231435513142097
#
# Briggs(2,10^-3) = 0.6933818297000016
# Briggs(2,10^-3) - ln(2)= 0.00023464914005633108
#
# Briggs(2,10^-4) = 0.693176505910742
# Briggs(2,10^-4) - ln(2)= 2.932535079669396e-05
#
# Briggs(2,10^-5) = 0.6931490133574698
# Briggs(2,10^-5) - ln(2)= 1.8327975245258088e-06
#
# Briggs(2,10^-6) = 0.6931474097073078
# Briggs(2,10^-6) - ln(2)= 2.29147362529325e-07
#
# Briggs(2,10^-7) = 0.6931472104042768
# Briggs(2,10^-7) - ln(2)= 2.984433156161259e-08
